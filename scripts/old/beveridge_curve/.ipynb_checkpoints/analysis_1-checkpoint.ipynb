# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# Out:
# C:\Users\singhy\AppData\Local\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# C:\Users\singhy\AppData\Local\Temp\ipykernel_808\3635408121.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data_dir = "C:/Users/singhy/Desktop/Chicago/cps_data/inflation/raw_data/labor_data"
output_dir = "C:/Users/singhy/Desktop/Chicago/cps_data/inflation/output/data"

# %%
data = pd.read_csv(f"{output_dir}/clean_stocks.csv")

# %%
data
# Out:
#            date       E       U        P        Z  P_12m_change       V  \
# 0    1948-01-01   44679  2034.0   23.680   23.106     10.242086     NaN
# 1    1948-02-01   44533  2328.0   23.670   23.106      9.481961     NaN
# 2    1948-03-01   44683  2399.0   23.500   23.106      6.818182     NaN
# 3    1948-04-01   44379  2386.0   23.820   23.045      8.272727     NaN
# 4    1948-05-01   44796  2118.0   24.010   23.045      9.384966     NaN
# ..          ...     ...     ...      ...      ...           ...     ...
# 915  2024-04-01  158214  6492.0  313.207  112.639      3.357731  7919.0
# 916  2024-05-01  158430  6649.0  313.225      NaN      3.250210  8230.0
# 917  2024-06-01  158548  6811.0  313.049      NaN      2.975629  7910.0
# 918  2024-07-01  158637  7163.0  313.534      NaN      2.923566  7673.0
# 919  2024-08-01  158779  7115.0      NaN      NaN           NaN     NaN
#
#        V_rate  tot_quits  vacancy_stock  tot_hires  tot_layoffs    U_rate  \
# 0         NaN        NaN            NaN        NaN          NaN  4.354248
# 1         NaN        NaN            NaN        NaN          NaN  4.967884
# 2         NaN        NaN            NaN        NaN          NaN  5.095366
# 3         NaN        NaN            NaN        NaN          NaN  5.102106
# 4         NaN        NaN            NaN        NaN          NaN  4.514644
# ..        ...        ...            ...        ...          ...       ...
# 915  4.807961     3452.0         7919.0     5615.0       1542.0  3.941569
# 916  4.985492     3403.0         8230.0     5655.0       1678.0  4.027769
# 917  4.783532     3214.0         7910.0     5248.0       1560.0  4.118917
# 918  4.627865     3277.0         7673.0     5521.0       1762.0  4.320265
# 919       NaN        NaN            NaN        NaN          NaN  4.288883
#
#      tightness
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 915   1.219809
# 916   1.237780
# 917   1.161357
# 918   1.071199
# 919        NaN
#
# [920 rows x 14 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert 'date' column to datetime if not already done
data['date'] = pd.to_datetime(data['date'])

# Drop rows with missing values in 'tightness', 'P_12m_change', or 'U_rate'
data = data.dropna(subset=['tightness', 'P_12m_change', 'U_rate'])

# Create a new figure
plt.figure(figsize=(12, 15))

# Plot Tightness
plt.subplot(3, 1, 1)  # 3 rows, 1 column, 1st subplot
plt.plot(data['date'], data['tightness'], linestyle='-', color='b')
plt.ylabel('Tightness')
plt.title('Tightness Over Time')
plt.grid(True)

# Plot Inflation
plt.subplot(3, 1, 2)  # 3 rows, 1 column, 2nd subplot
plt.plot(data['date'], data['P_12m_change'], linestyle='--', color='r')
plt.ylabel('Inflation')
plt.title('Inflation Over Time')
plt.grid(True)

# Plot Unemployment Rate
plt.subplot(3, 1, 3)  # 3 rows, 1 column, 3rd subplot
plt.plot(data['date'], data['U_rate'], linestyle='-', color='g')
plt.xlabel('Date')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate Over Time')
plt.grid(True)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
import statsmodels.api as sm

# Assuming your data is in a DataFrame called 'data'
# Drop rows with missing values in the columns of interest
data_clean = data[['V_rate', 'U_rate', 'Z', 'P_12m_change']].dropna()

# Define the dependent and independent variables
X = data_clean[['U_rate', 'Z', 'P_12m_change']]
y = data_clean['V_rate']

# Add a constant to the independent variables matrix (intercept)
X = sm.add_constant(X)

# Fit the OLS regression model
model = sm.OLS(y, X).fit()

# Display the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 V_rate   R-squared:                       0.507
# Model:                            OLS   Adj. R-squared:                  0.505
# Method:                 Least Squares   F-statistic:                     299.5
# Date:                Thu, 12 Sep 2024   Prob (F-statistic):          9.63e-134
# Time:                        12:44:06   Log-Likelihood:                -1002.1
# No. Observations:                 879   AIC:                             2012.
# Df Residuals:                     875   BIC:                             2031.
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            5.2405      0.116     45.056      0.000       5.012       5.469
# U_rate          -0.3382      0.014    -24.357      0.000      -0.365      -0.311
# Z                0.0011      0.001      1.097      0.273      -0.001       0.003
# P_12m_change     0.1769      0.009     19.252      0.000       0.159       0.195
# ==============================================================================
# Omnibus:                       35.349   Durbin-Watson:                   0.066
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.709
# Skew:                           0.464   Prob(JB):                     2.38e-09
# Kurtosis:                       3.473   Cond. No.                         307.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
data_clean = data[['Z', 'tightness', 'P_12m_change']].dropna()

# Define the dependent and independent variables
X = data_clean[['Z', 'P_12m_change']]
y = data_clean['tightness']

# Add a constant to the independent variables matrix (intercept)
X = sm.add_constant(X)

# Fit the OLS regression model
model = sm.OLS(y, X).fit()

# Display the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              tightness   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     16.66
# Date:                Thu, 12 Sep 2024   Prob (F-statistic):           7.90e-08
# Time:                        12:44:15   Log-Likelihood:                -327.77
# No. Observations:                 879   AIC:                             661.5
# Df Residuals:                     876   BIC:                             675.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.5368      0.037     14.637      0.000       0.465       0.609
# Z                0.0012      0.000      2.506      0.012       0.000       0.002
# P_12m_change     0.0234      0.004      5.499      0.000       0.015       0.032
# ==============================================================================
# Omnibus:                      108.716   Durbin-Watson:                   0.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              147.692
# Skew:                           0.966   Prob(JB):                     8.49e-33
# Kurtosis:                       3.545   Cond. No.                         207.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert the 'date' column to datetime format using .loc to avoid the SettingWithCopyWarning
data.loc[:, 'date'] = pd.to_datetime(data['date'])

# Filter the data for the period May 2020 - Present
filtered_data = data[data['date'] >= '2020-05-01']

# Plot the Beveridge curve: Unemployment Rate vs Vacancy Rate
plt.figure(figsize=(10, 6))
plt.plot(filtered_data['U_rate'], filtered_data['V_rate'], marker='o', linestyle='-')
plt.xlabel('Unemployment Rate (%)')
plt.ylabel('Vacancy Rate')
plt.title('Beveridge Curve (May 2020 - Present)')
plt.grid(True)
plt.show()

# %%
# Calculate the necessary variables
u = data['U_rate']
v = data['V_rate']
v_u = data['tightness'] 
z = data['Z']
pi = data['P_12m_change']

# %%
# Calculate Standard Deviation
std_dev = {
    'u': np.std(u),
    'v': np.std(v),
    'v/u': np.std(v_u),
    'z': np.std(z), 
    'pi': np.std(pi)
}

# Calculate Quarterly Autocorrelation
autocorr = {
    'u': u.autocorr(lag=3),  # Quarterly autocorrelation
    'v': v.autocorr(lag=3),
    'v/u': v_u.autocorr(lag=3),
    'z': z.autocorr(lag=3), 
    'pi': pi.autocorr(lag=3)
}

# Calculate Correlation Matrix
corr_matrix = pd.DataFrame({
    'u': u,
    'v': v,
    'v/u': v_u,
    'z': z, 
    'pi': pi
}).corr()

# Prepare the summary table
summary_table = pd.DataFrame({
    'Standard Deviation': std_dev,
    'Quarterly Autocorrelation': autocorr
}).T

# Add the correlation matrix to the summary table using pd.concat
summary_table = pd.concat([summary_table, corr_matrix])

# Format the table to match the desired output
summary_table = summary_table.round(3)
print(summary_table)
# Out:
#                                u      v    v/u       z     pi
# Standard Deviation         1.849  1.077  0.358  25.428  2.814
# Quarterly Autocorrelation  0.914  0.965  0.955   1.000  0.953
# u                          1.000 -0.546 -0.801  -0.023  0.079
# v                         -0.546  1.000  0.867  -0.025  0.412
# v/u                       -0.801  0.867  1.000   0.058  0.171
# z                         -0.023 -0.025  0.058   1.000 -0.139
# pi                         0.079  0.412  0.171  -0.139  1.000
