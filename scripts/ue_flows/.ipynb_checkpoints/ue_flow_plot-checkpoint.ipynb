# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# Specify directories 
output_dir = "C:/Users/singhy/Desktop/Chicago/cps_data/inflation/output"

# %%
data = pd.read_csv(f"{output_dir}/data/ue_flows.csv")

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
data_16_24 = data[data['date'] >= '2016-01-01']

# %%
data_16_24
# Out:
#           date  job_finding_rate  16_19_jf_avg
# 311 2016-01-01          0.255933      0.268794
# 312 2016-02-01          0.219034      0.268794
# 313 2016-03-01          0.229745      0.268794
# 314 2016-04-01          0.223875      0.268794
# 315 2016-05-01          0.260716      0.268794
# ..         ...               ...           ...
# 411 2024-05-01          0.265604      0.268794
# 412 2024-06-01          0.262957      0.268794
# 413 2024-07-01          0.244311      0.268794
# 414 2024-08-01          0.272242      0.268794
# 415 2024-09-01          0.294118      0.268794
#
# [105 rows x 3 columns]

# %%
# Create the plot 
plt.figure(figsize=(12, 6)) 
    
# Plot both lines
plt.plot(data_16_24['date'], data_16_24['job_finding_rate'])
# Customize the plot
plt.title('UE')
#plt.ylim(.15,.35)
plt.legend()
plt.savefig(f"{output_dir}/figures/ue_16_24.pdf", bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data.set_index('date', inplace = True)
data_quarterly = data.resample('Q').mean()

data_quarterly.reset_index(inplace=True)
# Out:
# C:\Users\singhy\AppData\Local\Temp\ipykernel_7944\1668882361.py:2: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   data_quarterly = data.resample('Q').mean()

# %%
# Create the plot 
plt.figure(figsize=(12, 6)) 
    
# Plot both lines
plt.plot(data_quarterly['date'], data_quarterly['job_finding_rate'])
# Customize the plot
plt.title('UE')
plt.ylim(.15,.35)
plt.legend()
plt.savefig(f"{output_dir}/figures/ue_long.pdf", bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data_quarterly_16 = data_quarterly[data_quarterly['date'] >= '2016-01-01']

# %%
# Create the plot 
plt.figure(figsize=(12, 6)) 
    
# Plot both lines
plt.plot(data_quarterly_16['date'], data_quarterly_16['job_finding_rate'])
# Customize the plot
plt.title('UE')
plt.ylim(.15,.35)
plt.legend()
plt.savefig(f"{output_dir}/figures/ue_quarterly.pdf", bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
